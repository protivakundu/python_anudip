# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
csv_file_path="C:/Users/Protiva/OneDrive/Desktop/Anudip_python/27 Excel/customer_data.csv"
d_frame=pd.read_csv(csv_file_path)
d_frame
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 0          01-01-2019          151200  Female  19.0         Single
# 1          02-01-2019          151201    Male  49.0         Single
# 2          03-01-2019          151202    Male  63.0        Married
# 3          04-01-2019          151203     NaN  18.0         Single
# 4          05-01-2019          151204    Male  27.0         Single
# ...               ...             ...     ...   ...            ...
# 2507       12-11-2025          153695  Female  57.0         Single
# 2508       13-11-2025          153696  Female  36.0        Married
# 2509       14-11-2025          153697    Male  22.0         Single
# 2510       15-11-2025          153698     NaN  44.0         Single
# 2511       16-11-2025          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 0             Kansas     Basic     Unemployment          Other      1.0
# ...

# %%
d_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2512 entries, 0 to 2511
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_date  2512 non-null   object
#  1   Transaction_ID    2512 non-null   int64
#  2   Gender            2484 non-null   object
#  3   Age               2470 non-null   float64
#  4   Marital_status    2512 non-null   object
#  5   State_names       2512 non-null   object
#  6   Segment           2512 non-null   object
#  7   Employees_status  2486 non-null   object
#  8   Payment_method    2512 non-null   object
#  9   Referal           2357 non-null   float64
#  10  Amount_spent      2270 non-null   float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 216.0+ KB

# %%
d_frame.duplicated().sum()
# Out:
# 0

# %%
d_frame.isnull().sum()
# Out:
# Transaction_date      0
# Transaction_ID        0
# Gender               28
# Age                  42
# Marital_status        0
# State_names           0
# Segment               0
# Employees_status     26
# Payment_method        0
# Referal             155
# Amount_spent        242
# dtype: int64

# %%
d_frame.describe().T     #.T use for traspose
# Out:
#                  count           mean         std        min          25%  \
# Transaction_ID  2512.0  152443.931131  724.580482  151200.00  151815.7500
# Age             2470.0      46.637652   18.186277      15.00      32.0000
# Referal         2357.0       0.652100    0.476405       0.00       0.0000
# Amount_spent    2270.0    1418.422577  878.507451       2.09     678.1925
#
#                        50%          75%        max
# Transaction_ID  152443.500  153071.2500  153699.00
# Age                 47.000      62.0000      78.00
# Referal              1.000       1.0000       1.00
# Amount_spent      1341.435    2038.1025    2999.98

# %%
#display object
d_frame.describe(include=object).T
# Out:
#                  count unique         top  freq
# Transaction_date  2512   2512  01-01-2019     1
# Gender            2484      2      Female  1356
# Marital_status    2512      2     Married  1473
# State_names       2512     50    Illinois    67
# Segment           2512      5       Basic  1136
# Employees_status  2486      4   Employees   946
# Payment_method    2512      3      PayPal  1168

# %%
d_frame["Referal"].value_counts()
# Out:
# Referal
# 1.0    1537
# 0.0     820
# Name: count, dtype: int64

# %%
d_frame["Referal"].isnull().value_counts()
# Out:
# Referal
# False    2357
# True      155
# Name: count, dtype: int64

# %%
d_frame["Referal"].fillna(0.0,inplace=True)
d_frame["Referal"].isnull().value_counts()
# Out:
# Referal
# False    2512
# Name: count, dtype: int64

# %%
d_frame["Age"].value_counts()
# Out:
# Age
# 54.0    51
# 43.0    50
# 55.0    48
# 24.0    47
# 53.0    46
#         ..
# 52.0    31
# 58.0    28
# 69.0    22
# 74.0    21
# 29.0    18
# Name: count, Length: 63, dtype: int64

# %%
d_frame["Age"].fillna(47,inplace=True)
d_frame["Age"].isnull().value_counts()
# Out:
# Age
# False    2512
# Name: count, dtype: int64

# %%
d_frame["Amount_spent"].value_counts()
# Out:
# Amount_spent
# 1264.73    2
# 61.35      2
# 1277.64    2
# 1397.09    2
# 1938.48    2
#           ..
# 2876.36    1
# 2557.92    1
# 1494.24    1
# 1094.78    1
# 1073.15    1
# Name: count, Length: 2250, dtype: int64

# %%
d_frame["Amount_spent"].fillna(round(1418.422577,2),inplace=True)
d_frame["Amount_spent"].isnull().value_counts()
# Out:
# Amount_spent
# False    2512
# Name: count, dtype: int64

# %%
d_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2512 entries, 0 to 2511
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_date  2512 non-null   object
#  1   Transaction_ID    2512 non-null   int64
#  2   Gender            2484 non-null   object
#  3   Age               2512 non-null   float64
#  4   Marital_status    2512 non-null   object
#  5   State_names       2512 non-null   object
#  6   Segment           2512 non-null   object
#  7   Employees_status  2486 non-null   object
#  8   Payment_method    2512 non-null   object
#  9   Referal           2512 non-null   float64
#  10  Amount_spent      2512 non-null   float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 216.0+ KB

# %%
d_frame["Gender"].value_counts()
# Out:
# Gender
# Female    1356
# Male      1128
# Name: count, dtype: int64

# %%
d_frame["Gender"].nunique()
# Out:
# 2

# %%
d_frame["Gender"].unique()
# Out:
# array(['Female', 'Male', nan], dtype=object)

# %%
d_frame["Gender"].fillna("Others",inplace=True)
d_frame["Gender"].unique()
# Out:
# array(['Female', 'Male', 'Others'], dtype=object)

# %%
d_frame["Employees_status"].value_counts()
# Out:
# Employees_status
# Employees        946
# workers          798
# self-employed    487
# Unemployment     255
# Name: count, dtype: int64

# %%
d_frame["Employees_status"].fillna("No mentioned",inplace=True)
d_frame["Employees_status"].isnull().value_counts()
# Out:
# Employees_status
# False    2512
# Name: count, dtype: int64

# %%
d_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2512 entries, 0 to 2511
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_date  2512 non-null   object
#  1   Transaction_ID    2512 non-null   int64
#  2   Gender            2512 non-null   object
#  3   Age               2512 non-null   float64
#  4   Marital_status    2512 non-null   object
#  5   State_names       2512 non-null   object
#  6   Segment           2512 non-null   object
#  7   Employees_status  2512 non-null   object
#  8   Payment_method    2512 non-null   object
#  9   Referal           2512 non-null   float64
#  10  Amount_spent      2512 non-null   float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 216.0+ KB

# %%
#cor-relation
correlation=d_frame["Age"].corr(d_frame["Amount_spent"])
print(correlation)
# Out:
# -0.02212819235755901

# %%
correlation=d_frame["Age"].corr(d_frame["Referal"])
print(correlation)
# Out:
# 0.012668612194532787

# %%
d_frame["Age"].value_counts()
# Out:
# Age
# 47.0    86
# 54.0    51
# 43.0    50
# 55.0    48
# 24.0    47
#         ..
# 52.0    31
# 58.0    28
# 69.0    22
# 74.0    21
# 29.0    18
# Name: count, Length: 63, dtype: int64

# %%
d_frame["Referal"].value_counts()
# Out:
# Referal
# 1.0    1537
# 0.0     975
# Name: count, dtype: int64

# %%
#seaborn heatmap for correlation
df=d_frame.select_dtypes(include="number")
sns.heatmap(df.corr(),cmap="coolwarm",annot=True)
# Out:
# <Axes: >

# %%
d_frame["State_names"].unique()
# Out:
# array(['Kansas', 'Illinois', 'New Mexico', 'Virginia', 'Connecticut',
#        'Hawaii', 'Florida', 'Vermont', 'California', 'Colorado', 'Iowa',
#        'South Carolina', 'New York', 'Maine', 'Maryland', 'Missouri',
#        'North Dakota', 'Ohio', 'Nebraska', 'Montana', 'Indiana',
#        'Wisconsin', 'Alabama', 'Arkansas', 'Pennsylvania',
#        'New Hampshire', 'Washington', 'Texas', 'Kentucky',
#        'Massachusetts', 'Wyoming', 'Louisiana', 'North Carolina',
#        'Rhode Island', 'West Virginia', 'Tennessee', 'Oregon', 'Alaska',
#        'Oklahoma', 'Nevada', 'New Jersey', 'Michigan', 'Utah', 'Arizona',
#        'South Dakota', 'Georgia', 'Idaho', 'Mississippi', 'Minnesota',
#        'Delaware'], dtype=object)

# %%
d_frame["State_names"].value_counts().head(10)
# Out:
# State_names
# Illinois         67
# Georgia          64
# Massachusetts    63
# Maine            62
# Kentucky         59
# Minnesota        59
# Missouri         57
# Arizona          56
# Delaware         56
# Arkansas         55
# Name: count, dtype: int64

# %%
d_frame["State_names"].value_counts().tail(10)
# Out:
# State_names
# Utah             43
# New Hampshire    43
# Indiana          43
# Ohio             43
# Alabama          42
# Alaska           41
# Nebraska         41
# North Dakota     41
# Kansas           41
# Tennessee        39
# Name: count, dtype: int64

# %%
#sort data
#d_frame.sort_values(by=[coulmn_name])
d_frame.sort_values(by=["State_names"]).head(10)
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 617        09-09-2020          151805    Male  43.0        Married
# 1856       31-01-2024          153044  Female  18.0        Married
# 2443       09-09-2025          153631    Male  60.0        Married
# 2441       07-09-2025          153629    Male  18.0         Single
# 1023       20-10-2021          152211  Female  30.0        Married
# 1853       28-01-2024          153041    Male  18.0        Married
# 1097       02-01-2022          152285  Female  59.0        Married
# 1109       14-01-2022          152297  Female  73.0        Married
# 2379       07-07-2025          153567  Female  34.0         Single
# 2348       06-06-2025          153536  Female  27.0        Married
#
#      State_names   Segment Employees_status Payment_method  Referal  \
# 617      Alabama    Silver        Employees         PayPal      1.0
# 1856     Alabama    Silver          workers         PayPal      0.0
# ...

# %%
d_frame.sort_values(by=["Amount_spent"],ascending=False).head(10)
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 17         18-01-2019          151217  Female  77.0        Married
# 485        30-04-2020          151673    Male  65.0        Married
# 2279       29-03-2025          153467  Female  78.0         Single
# 589        12-08-2020          151777    Male  51.0         Single
# 743        13-01-2021          151931    Male  44.0         Single
# 2367       25-06-2025          153555    Male  39.0         Single
# 101        12-04-2019          151296  Female  33.0        Married
# 1254       08-06-2022          152442  Female  16.0        Married
# 1123       28-01-2022          152311    Male  35.0        Married
# 1177       23-03-2022          152365  Female  30.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 17        New Mexico  Platinum          workers           Card      0.0
# 485          Arizona      Gold    self-employed         PayPal      1.0
# ...

# %%
#top data
d_frame.nlargest(5,"Amount_spent")
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 17         18-01-2019          151217  Female  77.0        Married
# 485        30-04-2020          151673    Male  65.0        Married
# 2279       29-03-2025          153467  Female  78.0         Single
# 589        12-08-2020          151777    Male  51.0         Single
# 743        13-01-2021          151931    Male  44.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 17        New Mexico  Platinum          workers           Card      0.0
# 485          Arizona      Gold    self-employed         PayPal      1.0
# 2279         Arizona    Silver        Employees         PayPal      1.0
# 589   North Carolina   Missing        Employees         PayPal      1.0
# 743         Illinois     Basic        Employees           Card      1.0
#
#       Amount_spent
# 17         2999.98
# 485        2998.62
# 2279       2997.21
# 589        2997.15
# 743        2996.82

# %%
#small data
d_frame.nsmallest(5,"Amount_spent")
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 2468       04-10-2025          153656  Female  73.0        Married
# 568        22-07-2020          151756    Male  46.0         Single
# 2401       29-07-2025          153589  Female  60.0         Single
# 962        20-08-2021          152150  Female  56.0        Married
# 860        10-05-2021          152048    Male  26.0         Single
#
#          State_names Segment Employees_status Payment_method  Referal  \
# 2468        Michigan    Gold        Employees         PayPal      1.0
# 568   South Carolina    Gold          workers         PayPal      0.0
# 2401        Maryland  Silver        Employees         PayPal      1.0
# 962           Nevada   Basic          workers          Other      1.0
# 860         Maryland  Silver     Unemployment         PayPal      1.0
#
#       Amount_spent
# 2468          2.09
# 568           2.16
# 2401          2.84
# 962           5.31
# 860           5.55

# %%
d_frame.loc[(d_frame["Age"]>=18) & (d_frame["Age"]<=27)].head(10)
# Out:
#    Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 0        01-01-2019          151200  Female  19.0         Single
# 3        04-01-2019          151203  Others  18.0         Single
# 4        05-01-2019          151204    Male  27.0         Single
# 14       15-01-2019          151214    Male  24.0        Married
# 20       21-01-2019          151220  Female  19.0        Married
# 25       26-01-2019          151225    Male  25.0        Married
# 31       01-02-2019          151231  Female  21.0         Single
# 40       10-02-2019          151240  Female  21.0        Married
# 55       25-02-2019          151255    Male  26.0         Single
# 71       13-03-2019          151266    Male  24.0        Married
#
#      State_names   Segment Employees_status Payment_method  Referal  \
# 0         Kansas     Basic     Unemployment          Other      1.0
# 3       Virginia  Platinum          workers           Card      1.0
# ...

# %%
d_frame["Transaction_date"]=pd.to_datetime(d_frame["Transaction_date"],format="%d-%m-%Y")
d_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2512 entries, 0 to 2511
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_date  2512 non-null   datetime64[ns]
#  1   Transaction_ID    2512 non-null   int64
#  2   Gender            2512 non-null   object
#  3   Age               2512 non-null   float64
#  4   Marital_status    2512 non-null   object
#  5   State_names       2512 non-null   object
#  6   Segment           2512 non-null   object
#  7   Employees_status  2512 non-null   object
#  8   Payment_method    2512 non-null   object
#  9   Referal           2512 non-null   float64
#  10  Amount_spent      2512 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(6)
# memory usage: 216.0+ KB

# %%
d_frame.loc[(d_frame["Marital_status"]=="Single") & ((d_frame["Employees_status"]=="workers") | (d_frame["Employees_status"]== "self-employed") ) & (d_frame["Gender"]=="Female")].head(10)
# Out:
#     Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 42        2019-02-12          151242  Female  16.0         Single
# 48        2019-02-18          151248  Female  64.0         Single
# 70        2019-03-12          151265  Female  30.0         Single
# 77        2019-03-19          151272  Female  69.0         Single
# 83        2019-03-25          151278  Female  61.0         Single
# 92        2019-04-03          151287  Female  45.0         Single
# 94        2019-04-05          151289  Female  41.0         Single
# 95        2019-04-06          151290  Female  51.0         Single
# 106       2019-04-17          151301  Female  53.0         Single
# 113       2019-04-24          151301  Female  53.0         Single
#
#        State_names   Segment Employees_status Payment_method  Referal  \
# 42           Texas      Gold    self-employed         PayPal      1.0
# 48   Massachusetts  Platinum    self-employed           Card      1.0
# ...

# %%
d_frame["Marital_status"].value_counts()
# Out:
# Marital_status
# Married    1473
# Single     1039
# Name: count, dtype: int64

# %%
#group by maximum,minimum,count,sum
d_frame[["Age","Amount_spent","Employees_status"]].groupby(d_frame["Gender"]).max()
# Out:
#          Age  Amount_spent Employees_status
# Gender
# Female  78.0       2999.98          workers
# Male    78.0       2998.62          workers
# Others  72.0       2909.85          workers

# %%
d_frame[["Gender","Marital_status","Age","Amount_spent","Employees_status"]].groupby(["Gender","Marital_status"]).count()
# Out:
#                        Age  Amount_spent  Employees_status
# Gender Marital_status
# Female Married         788           788               788
#        Single          568           568               568
# Male   Married         668           668               668
#        Single          460           460               460
# Others Married          17            17                17
#        Single           11            11                11

# %%
pd.crosstab(d_frame["Marital_status"],d_frame["Payment_method"],margins=True,margins_name="Total")
# Out:
# Payment_method  Card  Other  PayPal  Total
# Marital_status
# Married          441    362     670   1473
# Single           308    233     498   1039
# Total            749    595    1168   2512

# %%
pd.crosstab(d_frame["Marital_status"],d_frame["Gender"],margins=True,margins_name="Total")
# Out:
# Gender          Female  Male  Others  Total
# Marital_status
# Married            788   668      17   1473
# Single             568   460      11   1039
# Total             1356  1128      28   2512

# %%
d_frame["Year"]=d_frame["Transaction_date"].dt.year

# %%
d_frame["Amount_spent"].groupby(d_frame["Year"]).sum()
# Out:
# Year
# 2019    540643.08
# 2020    505357.97
# 2021    492541.18
# 2022    539543.57
# 2023    510895.16
# 2024    520218.80
# 2025    453877.13
# Name: Amount_spent, dtype: float64

# %%
plt.plot(d_frame["Amount_spent"].groupby(d_frame["Year"]).sum().index,d_frame["Amount_spent"].groupby(d_frame["Year"]).sum(),marker="o")
plt.title("Yearly amount spent")
plt.grid()
plt.show()

# %% [markdown]
# According to the above graph, we can see that in the year 2019 we had very good sales but gradually decreased in the years 2020 and 2021, then it was revived and reached the highest salescompared to the last two years in 2022.

# %%
plt.bar(d_frame["Payment_method"].value_counts().index,d_frame["Payment_method"].value_counts())
plt.show()

# %%
plt.bar(d_frame["Year"].value_counts().index,d_frame["Year"].value_counts())
plt.show()

# %%
plt.barh(d_frame["Employees_status"].value_counts().index,d_frame["Employees_status"].value_counts())
plt.show()

# %%
plt.pie(d_frame["Marital_status"].value_counts(),labels=d_frame["Marital_status"].value_counts().index,autopct="%1.1f%%")
plt.show()

# %%
plt.pie(d_frame["Employees_status"].value_counts(),labels=d_frame["Employees_status"].value_counts().index,autopct="%1.1f%%")
plt.show()

# %%
plt.pie(d_frame["Payment_method"].value_counts(),labels=d_frame["Payment_method"].value_counts().index,autopct="%1.1f%%")
plt.show()

# %%
d_frame["Gender"].value_counts().plot(kind="pie",autopct="%1.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
d_frame[["Gender","Marital_status","Age","Payment_method"]].groupby(["Gender","Marital_status","Payment_method"]).sum()
# Out:
#                                           Age
# Gender Marital_status Payment_method
# Female Married        Card            11181.0
#                       Other            8746.0
#                       PayPal          16852.0
#        Single         Card             8351.0
#                       Other            6330.0
#                       PayPal          12092.0
# Male   Married        Card             8815.0
#                       Other            8012.0
#                       PayPal          14031.0
#        Single         Card             5776.0
#                       Other            4931.0
#                       PayPal          10866.0
# Others Married        Card              273.0
#                       Other             144.0
#                       PayPal            396.0
#        Single         Card              153.0
#                       Other              69.0
#                       PayPal            151.0

# %%
d_frame.to_csv("C:/Users/Protiva/OneDrive/Desktop/Anudip_python/27 Excel/Cleaned_customer_data.csv",index=False)

# %%
arr=np.array([[1,2,3],[4,5,6]])
arr1=np.array([[4,5,6]])
arr3=np.concatenate((arr,arr1),axis=0)
print(arr3)
print(arr1.shape)
print(arr.mean())
print(np.sum(arr))
# Out:
# [[1 2 3]
#  [4 5 6]
#  [4 5 6]]
# (1, 3)
# 3.5
# 21

# %%
d_frame
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 0          2019-01-01          151200  Female  19.0         Single
# 1          2019-01-02          151201    Male  49.0         Single
# 2          2019-01-03          151202    Male  63.0        Married
# 3          2019-01-04          151203  Others  18.0         Single
# 4          2019-01-05          151204    Male  27.0         Single
# ...               ...             ...     ...   ...            ...
# 2507       2025-11-12          153695  Female  57.0         Single
# 2508       2025-11-13          153696  Female  36.0        Married
# 2509       2025-11-14          153697    Male  22.0         Single
# 2510       2025-11-15          153698  Others  44.0         Single
# 2511       2025-11-16          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 0             Kansas     Basic     Unemployment          Other      1.0
# ...

# %%
d_frame["Age"].corr(d_frame["Amount_spent"])
# Out:
# -0.02212819235755901

# %%
d_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2512 entries, 0 to 2511
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_date  2512 non-null   datetime64[ns]
#  1   Transaction_ID    2512 non-null   int64
#  2   Gender            2512 non-null   object
#  3   Age               2512 non-null   float64
#  4   Marital_status    2512 non-null   object
#  5   State_names       2512 non-null   object
#  6   Segment           2512 non-null   object
#  7   Employees_status  2512 non-null   object
#  8   Payment_method    2512 non-null   object
#  9   Referal           2512 non-null   float64
#  10  Amount_spent      2512 non-null   float64
#  11  Year              2512 non-null   int32
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(1), object(6)
# memory usage: 225.8+ KB

# %%
#pivot tabel
pd.pivot_table(d_frame,index=["Gender"],values=["Amount_spent"],aggfunc=['mean'])
# Out:
#                mean
#        Amount_spent
# Gender
# Female  1427.943857
# Male    1408.674787
# Others  1349.995000

# %%
pd.pivot_table(d_frame,index=["Gender","Age"],values=["Amount_spent"],aggfunc=["sum"])
# Out:
#                      sum
#             Amount_spent
# Gender Age
# Female 15.0     28969.69
#        16.0     28078.88
#        17.0     22451.39
#        18.0     37345.66
#        19.0     26861.06
# ...                  ...
# Others 53.0       467.43
#        57.0       882.42
#        62.0      4110.54
#        67.0      5883.85
#        72.0       842.61
#
# [143 rows x 1 columns]

# %%
pd.pivot_table(d_frame,index=["Gender"],values=["Amount_spent"],aggfunc=["sum"])
# Out:
#                 sum
#        Amount_spent
# Gender
# Female   1936291.87
# Male     1588985.16
# Others     37799.86

# %%
pd.pivot_table(d_frame,index=["State_names","Gender","Age"],values=["Amount_spent"],columns=["Segment"],aggfunc=["count"],fill_value=0)
# Out:
#                                count
#                         Amount_spent
# Segment                        Basic Gold Missing Platinum Silver
# State_names Gender Age
# Alabama     Female 17.0            0    0       0        1      0
#                    18.0            0    0       0        0      1
#                    21.0            0    0       0        0      1
#                    24.0            1    0       0        0      0
#                    26.0            0    0       0        0      1
# ...                              ...  ...     ...      ...    ...
# Wyoming     Male   58.0            0    0       0        0      1
#                    64.0            0    0       0        0      1
#                    70.0            1    0       0        0      0
#                    71.0            1    0       0        0      0
#                    76.0            0    0       0        1      0
#
# [2072 rows x 5 columns]

# %%
d_frame[["Gender","Segment","Amount_spent"]].groupby(["Gender","Segment"]).sum()
# Out:
#                  Amount_spent
# Gender Segment
# Female Basic        874127.08
#        Gold         196138.63
#        Missing      145605.37
#        Platinum     333772.33
#        Silver       386648.46
# Male   Basic        715520.65
#        Gold         141999.41
#        Missing      131121.16
#        Platinum     301122.50
#        Silver       299221.44
# Others Basic         14719.98
#        Gold           5855.29
#        Missing        2977.75
#        Platinum       7924.53
#        Silver         6322.31

# %%
pd.pivot_table(d_frame,index=["State_names","Segment"],values=["Amount_spent"],aggfunc=["sum"],margins=True,margins_name="Total",fill_value=0)
# Out:
#                               sum
#                      Amount_spent
# State_names Segment
# Alabama     Basic        15661.81
#             Gold          5078.68
#             Missing       3086.37
#             Platinum     16108.31
#             Silver       15646.90
# ...                           ...
# Wyoming     Basic        39271.86
#             Gold          1107.68
#             Platinum      7441.88
#             Silver       11592.86
# Total                  3563076.89
#
# [247 rows x 1 columns]

# %%
d_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2512 entries, 0 to 2511
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_date  2512 non-null   datetime64[ns]
#  1   Transaction_ID    2512 non-null   int64
#  2   Gender            2512 non-null   object
#  3   Age               2512 non-null   float64
#  4   Marital_status    2512 non-null   object
#  5   State_names       2512 non-null   object
#  6   Segment           2512 non-null   object
#  7   Employees_status  2512 non-null   object
#  8   Payment_method    2512 non-null   object
#  9   Referal           2512 non-null   float64
#  10  Amount_spent      2512 non-null   float64
#  11  Year              2512 non-null   int32
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(1), object(6)
# memory usage: 225.8+ KB

# %%
pd.pivot_table(d_frame,index=["Gender","Employees_status"],values=["Amount_spent"],aggfunc=["sum"],margins=True,margins_name="True")
# Out:
#                                  sum
#                         Amount_spent
# Gender Employees_status
# Female Employees           730711.92
#        No mentioned         26930.78
#        Unemployment        188469.05
#        self-employed       396773.24
#        workers             593406.88
# Male   Employees           615402.59
#        No mentioned          3814.93
#        Unemployment        157689.21
#        self-employed       306517.74
#        workers             505560.69
# Others Employees            14907.46
#        No mentioned          1418.42
#        Unemployment           880.49
#        self-employed         6056.42
#        workers              14537.07
# True                      3563076.89

# %%
pd.pivot_table(d_frame,index=["Gender","Employees_status"],values=["Amount_spent"],columns=["Segment"],aggfunc=["sum","count"],margins=True,margins_name="Total",fill_value=0.00)
# Out:
#                                  sum                                   \
#                         Amount_spent
# Segment                        Basic       Gold    Missing   Platinum
# Gender Employees_status
# Female Employees           304766.68   91410.43   54980.35  119175.74
#        No mentioned         16499.03    4561.40    1928.10    1226.06
#        Unemployment         97256.50   11737.86   10337.45   39393.12
#        self-employed       197001.22   30851.18   35231.16   67010.03
#        workers             258603.65   57577.76   43128.31  106967.38
# Male   Employees           291810.50   47437.04   50622.56  103324.17
#        No mentioned          1089.30       0.00       0.00    2396.43
#        Unemployment         65639.68   13443.05    9809.56   38852.92
#        self-employed       141539.78   30695.93   28058.40   52327.02
#        workers             215441.39   50423.39   42630.64  104221.96
# ...

# %%
#advanced pivot table filtering
table=pd.pivot_table(d_frame,index=["Gender","Employees_status"],values=["Amount_spent"],aggfunc=["sum"],margins=True,margins_name="Total")
table.query("Employees_status==['workers'] & Gender==['Male']")
# Out:
#                                  sum
#                         Amount_spent
# Gender Employees_status
# Male   workers             505560.69

# %%
#import pandas, matplotlib and seaborn library
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Read the csv file
csv_file="C:/Users/Protiva/OneDrive/Desktop/Anudip_python/archive (5)/supermarket_sales - Sheet1.csv"
d_frame=pd.read_csv(csv_file)
d_frame
# Out:
#        Invoice ID Branch       City Customer type  Gender  \
# 0     750-67-8428      A     Yangon        Member  Female
# 1     226-31-3081      C  Naypyitaw        Normal  Female
# 2     631-41-3108      A     Yangon        Normal    Male
# 3     123-19-1176      A     Yangon        Member    Male
# 4     123-19-1176      A     Yangon        Member    Male
# ...           ...    ...        ...           ...     ...
# 998   233-67-5758      C  Naypyitaw        Normal    Male
# 999   303-96-2227      B   Mandalay        Normal  Female
# 1000  727-02-1313      A     Yangon        Member    Male
# 1001  347-56-2442      A     Yangon        Normal    Male
# 1002  849-09-3807      A     Yangon        Member  Female
#
#                 Product line  Unit price  Quantity   Tax 5%      Total  \
# 0          Health and beauty       74.69       7.0  26.1415   548.9715
# 1     Electronic accessories       15.28       5.0   3.8200    80.2200
# ...

# %%
#Display information
d_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1003 entries, 0 to 1002
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1003 non-null   object
#  1   Branch                   1003 non-null   object
#  2   City                     1003 non-null   object
#  3   Customer type            1003 non-null   object
#  4   Gender                   999 non-null    object
#  5   Product line             1003 non-null   object
#  6   Unit price               1003 non-null   float64
#  7   Quantity                 996 non-null    float64
#  8   Tax 5%                   1003 non-null   float64
#  9   Total                    1003 non-null   float64
#  10  Date                     1003 non-null   object
#  11  Time                     1003 non-null   object
#  12  Payment                  996 non-null    object
#  13  cogs                     1003 non-null   float64
# ...

# %%
#Find null values in every columns
d_frame.isnull().sum()
# Out:
# Invoice ID                    0
# Branch                        0
# City                          0
# Customer type                 0
# Gender                        4
# Product line                  0
# Unit price                    0
# Quantity                      7
# Tax 5%                        0
# Total                         0
# Date                          0
# Time                          0
# Payment                       7
# cogs                          0
# gross margin percentage       0
# gross income                  0
# Rating                        5
# Unnamed: 17                1003
# Unnamed: 18                1003
# Unnamed: 19                1000
# dtype: int64

# %%
#Counting the occurence of the gender
d_frame["Gender"].value_counts()
# Out:
# Gender
# Male      500
# Female    499
# Name: count, dtype: int64

# %%
#Display statistical things of object
d_frame.describe(include=object).T
# Out:
#               count unique                  top freq
# Invoice ID     1003   1000          123-19-1176    2
# Branch         1003      3                    A  341
# City           1003      3               Yangon  341
# Customer type  1003      2               Member  504
# Gender          999      2                 Male  500
# Product line   1003      6  Fashion accessories  178
# Date           1003     89           02-07-2019   20
# Time           1003    506                19:48    7
# Payment         996      3              Ewallet  343
# Unnamed: 19       3      3             13:23:00    1

# %%
#Fill the null values
d_frame["Gender"].fillna("Other",inplace=True)

# %%
d_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1003 entries, 0 to 1002
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1003 non-null   object
#  1   Branch                   1003 non-null   object
#  2   City                     1003 non-null   object
#  3   Customer type            1003 non-null   object
#  4   Gender                   1003 non-null   object
#  5   Product line             1003 non-null   object
#  6   Unit price               1003 non-null   float64
#  7   Quantity                 996 non-null    float64
#  8   Tax 5%                   1003 non-null   float64
#  9   Total                    1003 non-null   float64
#  10  Date                     1003 non-null   object
#  11  Time                     1003 non-null   object
#  12  Payment                  996 non-null    object
#  13  cogs                     1003 non-null   float64
# ...

# %%
#Display statistical things
d_frame.describe().T
# Out:
#                           count        mean           std        min  \
# Unit price               1003.0   55.673809  2.645790e+01  10.080000
# Quantity                  996.0    5.524096  2.922865e+00   1.000000
# Tax 5%                   1003.0   15.405290  1.170102e+01   0.508500
# Total                    1003.0  323.511093  2.457213e+02  10.678500
# cogs                     1003.0  308.105803  2.340203e+02  10.170000
# gross margin percentage  1003.0    4.761905  8.886215e-16   4.761905
# gross income             1003.0   15.405290  1.170102e+01   0.508500
# Rating                    998.0    6.974449  1.717045e+00   4.000000
# Unnamed: 17                 0.0         NaN           NaN        NaN
# Unnamed: 18                 0.0         NaN           NaN        NaN
#
#                                 25%         50%         75%          max
# Unit price                33.050000   55.390000   77.825000    99.960000
# ...

# %%
#Fill the null values
d_frame["Quantity"].fillna(5.0,inplace=True)

# %%
d_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1003 entries, 0 to 1002
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1003 non-null   object
#  1   Branch                   1003 non-null   object
#  2   City                     1003 non-null   object
#  3   Customer type            1003 non-null   object
#  4   Gender                   1003 non-null   object
#  5   Product line             1003 non-null   object
#  6   Unit price               1003 non-null   float64
#  7   Quantity                 1003 non-null   float64
#  8   Tax 5%                   1003 non-null   float64
#  9   Total                    1003 non-null   float64
#  10  Date                     1003 non-null   object
#  11  Time                     1003 non-null   object
#  12  Payment                  996 non-null    object
#  13  cogs                     1003 non-null   float64
# ...

# %%
#Find the unique value from the Payment column
d_frame["Payment"].unique()
# Out:
# array(['Ewallet', 'Cash', 'Credit card', nan], dtype=object)

# %%
#Fill the null values
d_frame["Payment"].fillna("Not mentioned",inplace=True)
d_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1003 entries, 0 to 1002
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1003 non-null   object
#  1   Branch                   1003 non-null   object
#  2   City                     1003 non-null   object
#  3   Customer type            1003 non-null   object
#  4   Gender                   1003 non-null   object
#  5   Product line             1003 non-null   object
#  6   Unit price               1003 non-null   float64
#  7   Quantity                 1003 non-null   float64
#  8   Tax 5%                   1003 non-null   float64
#  9   Total                    1003 non-null   float64
#  10  Date                     1003 non-null   object
#  11  Time                     1003 non-null   object
#  12  Payment                  1003 non-null   object
#  13  cogs                     1003 non-null   float64
# ...

# %%
#Fill the null values
d_frame["Rating"].fillna(round(6.974449,2),inplace=True)

#Find null values in every columns
d_frame.isnull().sum()
# Out:
# Invoice ID                    0
# Branch                        0
# City                          0
# Customer type                 0
# Gender                        0
# Product line                  0
# Unit price                    0
# Quantity                      0
# Tax 5%                        0
# Total                         0
# Date                          0
# Time                          0
# Payment                       0
# cogs                          0
# gross margin percentage       0
# gross income                  0
# Rating                        0
# Unnamed: 17                1003
# Unnamed: 18                1003
# Unnamed: 19                1000
# dtype: int64

# %%
#Find the duplictes
d_frame.duplicated(keep=False).sum()
# Out:
# 6

# %%
#Drop all the duplicates data
d_frame.drop_duplicates(inplace=True)

# %%
#Find the duplicate data
d_frame.duplicated().sum()
# Out:
# 0

# %%
#Diplay top 10 data
d_frame.head(10)
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 0   750-67-8428      A     Yangon        Member  Female
# 1   226-31-3081      C  Naypyitaw        Normal  Female
# 2   631-41-3108      A     Yangon        Normal    Male
# 3   123-19-1176      A     Yangon        Member    Male
# 5   373-73-7910      A     Yangon        Normal    Male
# 6   699-14-3026      C  Naypyitaw        Normal    Male
# 7   355-53-5943      A     Yangon        Member  Female
# 8   315-22-5665      C  Naypyitaw        Normal  Female
# 9   665-32-9167      A     Yangon        Member  Female
# 10  692-92-5582      B   Mandalay        Member  Female
#
#               Product line  Unit price  Quantity   Tax 5%     Total  \
# 0        Health and beauty       74.69       7.0  26.1415  548.9715
# 1   Electronic accessories       15.28       5.0   3.8200   80.2200
# 2       Home and lifestyle       46.33       7.0  16.2155  340.5255
# 3        Health and beauty       58.22       8.0  23.2880  489.0480
# ...

# %%
#Drop unneccecery columns
d_frame=d_frame.drop("Unnamed: 17",axis=1)
d_frame=d_frame.drop("Unnamed: 18",axis=1)
d_frame=d_frame.drop("Unnamed: 19",axis=1)


d_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 1002
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   float64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
#Save the csv file
d_frame.to_csv("C:/Users/Protiva/OneDrive/Desktop/Anudip_python/archive (5)/Cleaned_supermarket_sales - Sheet1.csv",index=False)

# %% [markdown]
# Data analisys

# %%
#Display highest data based on Total column
d_frame.nlargest(5,"Total")
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 352  860-79-0874      C  Naypyitaw        Member  Female  Fashion accessories
# 169  687-47-8271      A     Yangon        Normal    Male  Fashion accessories
# 560  283-26-5248      C  Naypyitaw        Member  Female   Food and beverages
# 702  751-41-9720      C  Naypyitaw        Normal    Male   Home and lifestyle
# 999  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
#
#      Unit price  Quantity  Tax 5%    Total        Date   Time      Payment  \
# 352       99.30      10.0   49.65  1042.65   2/15/2019  14:53  Credit card
# 169       98.98      10.0   49.49  1039.29  02-08-2019  16:20  Credit card
# 560       98.52      10.0   49.26  1034.46   1/30/2019  20:23      Ewallet
# 702       97.50      10.0   48.75  1023.75  01-12-2019  16:18      Ewallet
# 999       97.38      10.0   48.69  1022.49  03-02-2019  17:16      Ewallet
#
# ...

# %%
d_frame.nlargest(5,"Rating")
# Out:
#      Customer ID Branch       City Customer type  Gender  \
# 61   285-68-5083      C  Naypyitaw        Member  Female
# 63   347-34-2234      B   Mandalay        Member  Female
# 161  423-57-2993      B   Mandalay        Normal    Male
# 389  725-56-0833      A     Yangon        Normal  Female
# 856  866-70-2814      B   Mandalay        Normal  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 61        Sports and travel       24.74       3.0   3.7110   77.9310
# 63        Sports and travel       55.07       9.0  24.7815  520.4115
# 161       Sports and travel       93.39       6.0  28.0170  588.3570
# 389       Health and beauty       32.32      10.0  16.1600  339.3600
# 856  Electronic accessories       52.79      10.0  26.3950  554.2950
#
#           Date   Time      Payment    cogs  gross margin percentage  \
# 61  2019-02-15  17:47  Credit card   74.22                 4.761905
# ...

# %%
#Groupby data particular columns
d_frame[["Branch","City","Total"]].groupby(["Branch","City"]).sum()
# Out:
#                         Total
# Branch City
# A      Yangon     106200.3705
# B      Mandalay   106197.6720
# C      Naypyitaw  110568.7065

# %%
#Groupby data particular columns(city and gender wise total amount)
d_frame[["City","Gender","Total"]].groupby(["City","Gender"]).sum()
# Out:
#                        Total
# City      Gender
# Mandalay  Female  52928.2950
#           Male    52981.3620
#           Other     288.0150
# Naypyitaw Female  61076.2950
#           Male    48883.2435
#           Other     609.1680
# Yangon    Female  52828.1040
#           Male    52931.2035
#           Other     441.0630

# %%
#Create bar chart
plt.bar(d_frame["Total"].groupby(d_frame["City"]).sum().index,d_frame["Total"].groupby(d_frame["City"]).sum(),color="green")
plt.title("Total sales of every city")
plt.xlabel("City")
plt.ylabel("Total of sales")
plt.show()

# %% [markdown]
# In Naypyitaw city, there sales are very high. But in mandalay and Yagon city, there's sales are low and similar. We have to do high sales in this city based on the demandable products.

# %%
#Create a pivot table city,product line and gender wise quantity
pd.pivot_table(d_frame,index=["City","Gender"],values=["Quantity"],columns=["Product line"],aggfunc=["sum"],fill_value=0.0,margins=True,margins_name="Total")
# Out:
#                                     sum                      \
#                                Quantity
# Product line     Electronic accessories Fashion accessories
# City      Gender
# Mandalay  Female                  156.0               177.0
#           Male                    160.0               120.0
#           Other                     0.0                 0.0
# Naypyitaw Female                  164.0               192.0
#           Male                    164.0               154.0
#           Other                     0.0                 0.0
# Yangon    Female                  163.0               161.0
#           Male                    154.0               102.0
#           Other                     4.0                 0.0
# Total                             965.0               906.0
#
#                                                                           \
#
# Product line     Food and beverages Health and beauty Home and lifestyle
# City      Gender
# ...

# %%
table=pd.pivot_table(d_frame,index=["City","Gender"],values=["Quantity"],columns=["Product line"],aggfunc=["sum"],fill_value=0.0)

#Create a bar plot
table.plot(kind="bar",figsize=(10,6))
plt.title("Visulazie the data based on quantity")
plt.ylabel("Quantity")
# Out:
# Text(0, 0.5, 'Quantity')

# %% [markdown]
# in Mandalay city, female customer high spent on Fashion accessories but they less spent on Health and beauty, I think there is a problem. They don't like those thing also the price of those other product is very high. Male customer high spent on Health and Beauty product but less spent on Food and beverages. Here we look that male customer like health products very much but  other product they buy but sales noy very much. But other customer don't spent any thing for any product. In Naypyitaw city, Female member spent money to much for Food and beverages, but also they buy less no of Helath and beauty. Male members in this city there don't to much money, here sales are less.Here also the same thing heppen, other customer don't buy anything. Also we have to find the problem . In Yangon city here we see the same thing, we have to see where is the problem, what the customers want.

# %%
#Create a pivot table Branch, city, Product line wise sum of unit price
pd.pivot_table(d_frame,index=["Branch","City"],values=["Unit price"],columns=["Product line"],aggfunc=["sum"])
# Out:
#                                     sum                      \
#                              Unit price
# Product line     Electronic accessories Fashion accessories
# Branch City
# A      Yangon                   3292.27             2890.19
# B      Mandalay                 2741.98             3400.32
# C      Naypyitaw                3069.52             3882.84
#
#                                                                           \
#
# Product line     Food and beverages Health and beauty Home and lifestyle
# Branch City
# A      Yangon               3188.52           2343.53            3629.97
# B      Mandalay             2777.00           3083.84            2775.70
# C      Naypyitaw            3780.02           2910.51            2445.04
#
#
#
# Product line     Sports and travel
# Branch City
# A      Yangon              3281.01
# B      Mandalay            3700.04
# C      Naypyitaw           2479.83

# %%
#Craete a pivot table  branch and city wise sum of product
table1=pd.pivot_table(d_frame,index=["Branch","City"],values=["Unit price"],columns=["Product line"],aggfunc=["sum"])
table1.plot(kind="bar",figsize=(8,6))
plt.title("Visualize data based on Unit price")
plt.ylabel("Unit Price")
# Out:
# Text(0, 0.5, 'Unit Price')

# %% [markdown]
# In Yangon city A branch,unit price of Home and lifestyle is high and Health and beauty is low. In Mandalay city B branch, Sports and travel unit price is high but unit price of Electronic accessories is low. In Naypyitaw city, unit price of Fashion accessories is very high but Home and lifestyle is low. We see that unit price of Health and beauty, Home and lifestyle, Sports and travel are very low some places. We have look into this what customer want.

# %%
#Create pivot table city and payment wise sum of Total amount
pd.pivot_table(d_frame,index=["City","Payment"],values=["Total"],aggfunc=["sum"])
# Out:
#                                 sum
#                               Total
# City      Payment
# Mandalay  Cash           34749.0255
#           Credit card    37311.4980
#           Ewallet        32631.2490
#           Not mentioned   1505.8995
# Naypyitaw Cash           43085.8575
#           Credit card    30327.4650
#           Ewallet        36855.8190
#           Not mentioned    299.5650
# Yangon    Cash           33348.4830
#           Credit card    32748.9645
#           Ewallet        39324.3690
#           Not mentioned    778.5540

# %%
table=pd.pivot_table(d_frame,index=["City","Payment"],values=["Total"],aggfunc=["sum"])

#Create a bar chart
table.plot(kind="barh",color="green",figsize=(8,5))
plt.title("Visualize sales based on Payment method")
plt.xlabel("Sales")
plt.ylabel("Payement method in every City")
# Out:
# Text(0, 0.5, 'Payement method in every City')

# %%
#Groupby Product wise maximum gross income
d_frame["gross income"].groupby(d_frame["Product line"]).max()
# Out:
# Product line
# Electronic accessories    44.8785
# Fashion accessories       49.6500
# Food and beverages        49.2600
# Health and beauty         45.2500
# Home and lifestyle        48.7500
# Sports and travel         47.7200
# Name: gross income, dtype: float64

# %%
#Create a pie chart product wise maximum gross income
plt.pie(d_frame["gross income"].groupby(d_frame["Product line"]).max(),labels=d_frame["gross income"].groupby(d_frame["Product line"]).max().index,autopct="%1.1f%%")
plt.title("Gross income of every product")
plt.show()

# %% [markdown]
# Gross income of Fashion accessories is very good, but Electronic accessories is less low, not to much. Others gross income is good. But we have to expend the gross income of every product.

# %%
#Create a bar chart product wise rating
plt.figure(figsize=(13,6))
plt.bar(d_frame["Rating"].groupby(d_frame["Product line"]).sum().index,d_frame["Rating"].groupby(d_frame["Product line"]).sum(),color="brown")
plt.title("Total sum of the rating on every product")
plt.xlabel("Product line")
plt.ylabel("Sum of Rating")
plt.show()

# %% [markdown]
# Fashion accessories and Food beverages gets highest rating, it's very good, that's mean it is highly demandable for all the customer. But Health and beauty produts get lowest rating and also thers. So we have to see it. I think it's price is high or customer does not to much like those product, but the rating is little bit low. So if there is a problem then solve it.

# %%
#Convert the date data object to date format
d_frame["Date"]=pd.to_datetime(d_frame["Date"],format="mixed")

#Create Month column
d_frame["Month"]=d_frame["Date"].dt.strftime("%B")
d_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 1002
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   float64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
#Groupby Month wise Total amount
d_frame["Total"].groupby(d_frame["Month"]).sum()
# Out:
# Month
# February     97219.374
# January     116291.868
# March       109455.507
# Name: Total, dtype: float64

# %%
#Create a line chart Month wise Total amount
plt.plot(d_frame["Total"].groupby(d_frame["Month"]).sum().index,d_frame["Total"].groupby(d_frame["Month"]).sum(),color="skyblue",marker="o",mfc="black")
plt.title("Sales of months")
plt.xlabel("Months")
plt.ylabel("Sales")
plt.grid(True)
plt.show()

# %% [markdown]
# In January, there is a highest sales in 2019 but in March , sales are very low in February. So we have to check what's the problem and solve it.

# %%
#Show top 10 data
d_frame.head(10)
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 0   750-67-8428      A     Yangon        Member  Female
# 1   226-31-3081      C  Naypyitaw        Normal  Female
# 2   631-41-3108      A     Yangon        Normal    Male
# 3   123-19-1176      A     Yangon        Member    Male
# 5   373-73-7910      A     Yangon        Normal    Male
# 6   699-14-3026      C  Naypyitaw        Normal    Male
# 7   355-53-5943      A     Yangon        Member  Female
# 8   315-22-5665      C  Naypyitaw        Normal  Female
# 9   665-32-9167      A     Yangon        Member  Female
# 10  692-92-5582      B   Mandalay        Member  Female
#
#               Product line  Unit price  Quantity   Tax 5%     Total  \
# 0        Health and beauty       74.69       7.0  26.1415  548.9715
# 1   Electronic accessories       15.28       5.0   3.8200   80.2200
# 2       Home and lifestyle       46.33       7.0  16.2155  340.5255
# 3        Health and beauty       58.22       8.0  23.2880  489.0480
# ...

# %%
#Creating heatmap for visualize the cor-relation
df=d_frame.select_dtypes(include="number")
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# See all the Cor_relation

# %%
#Create a pivot table
pivot_table=pd.pivot_table(d_frame,index=["City","Customer type","Gender"],values=["Total"],aggfunc=["sum"])

#Create bar chart
pivot_table.plot(kind="barh",color="seagreen",figsize=(8,6))
plt.title("Customer type wise Sales")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %% [markdown]
# In Mandalay city, who are the female member and male member, they buy many products. For their sales are very good. But in ths city others members , they do not spent money for anything. We have to look into it why they don't buy anything, which is their demandable things, which they want, so then we have to launch those things. But the normal female coustomer and normale male customer, they spent similar. Also we have to grow sales for their demandable products. In Naypyitaw city, who are female member , sales for their is very high . They buy many products. But male members spent money less than female members. I think they want any other products, so we have to know this and lauch those products. Same as others members. Same solution for normal customers and for Yangon city's customers.

# %%
#Create a pivot table gender and product wise sum of quantity
pd.pivot_table(d_frame,index=["Gender","Product line"],values=["Quantity"],aggfunc=["count","sum"])
# Out:
#                                  count      sum
#                               Quantity Quantity
# Gender Product line
# Female Electronic accessories       83    483.0
#        Fashion accessories          96    530.0
#        Food and beverages           89    505.0
#        Health and beauty            64    341.0
#        Home and lifestyle           79    498.0
#        Sports and travel            87    491.0
# Male   Electronic accessories       86    478.0
#        Fashion accessories          82    376.0
#        Food and beverages           84    438.0
#        Health and beauty            87    510.0
#        Home and lifestyle           81    413.0
#        Sports and travel            78    426.0
# Other  Electronic accessories        1      4.0
#        Food and beverages            1      8.0
#        Health and beauty             1      5.0
#        Sports and travel             1      5.0

# %%
#Create a pivot table
pivot_table1=pd.pivot_table(d_frame,index=["City"],values=["Total"],columns=["Product line"],aggfunc=["sum"])

#Create bar chart
pivot_table1.plot(kind="bar",figsize=(8,7))
plt.title("Visulalize product wise sales in a city")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %% [markdown]
# We see that city wise sales of every product.

# %%
#Groupby Month and product wise  maximum Total amount
d_frame[["Month","Product line","Total"]].groupby(["Month","Product line"]).max()
# Out:
#                                      Total
# Month    Product line
# February Electronic accessories   836.3040
#          Fashion accessories     1042.6500
#          Food and beverages       936.6000
#          Health and beauty        888.4050
#          Home and lifestyle       788.5080
#          Sports and travel        926.9505
# January  Electronic accessories   931.0350
#          Fashion accessories      874.1250
#          Food and beverages      1034.4600
#          Health and beauty        950.2500
#          Home and lifestyle      1023.7500
#          Sports and travel       1002.1200
# March    Electronic accessories   942.4485
#          Fashion accessories      943.2990
#          Food and beverages       935.2665
#          Health and beauty        922.6350
#          Home and lifestyle      1022.4900
#          Sports and travel        944.6220

# %%
#Create a pivot table month wise Total amount
bar_chart_table=pd.pivot_table(d_frame,index=["Month"],values=["Total"],columns=["Product line"],aggfunc=["max"])

#Create a bar chart
bar_chart_table.plot(kind="bar")
plt.title("Visualize product wise sales on months")
plt.ylabel("Maximum Sales")
# Out:
# Text(0, 0.5, 'Maximum Sales')

# %% [markdown]
# In February, maximum sales of Fashion accessories are very high, that's means customer like this product very much, but maximum sales of others product in this month are less than of this product. I thik there is a problem, somehow, customer don't like this to much on this month or the price is high or any other problem. In January, maximum sales of food and beverages is good, but others are not bad. Also look into the suspected problems. But in March, maximum sales of product is very good, highest is home and lifestyle products. Also other products's sales are very good, I think in this month solver the problems which is occurs. But also we have to look all time if there is a problem then solve it and grow the sales.

# %%
#Change column name of Invoice ID
d_frame=d_frame.rename(columns={"Invoice ID":"Customer ID"})

#Show top 5
d_frame.head(5)
# Out:
#    Customer ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 5  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69       7.0  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28       5.0   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33       7.0  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22       8.0  23.2880  489.0480 2019-01-27
# 5       Sports and travel       86.31       7.0  30.2085  634.3785 2019-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
#Grouby city and customer wise total customer 
d_frame[["City","Customer type","Customer ID"]].groupby(["City","Customer type"]).count()
# Out:
#                          Customer ID
# City      Customer type
# Mandalay  Member                 165
#           Normal                 167
# Naypyitaw Member                 169
#           Normal                 159
# Yangon    Member                 167
#           Normal                 173

# %%
#Create pivot table city and customer wise total no of customer
count_customer=pd.pivot_table(d_frame,index=["City"],values=["Customer ID"],columns=["Customer type"],aggfunc=["count"])
count_customer.plot(kind="bar")
plt.title("Visualize customer in every City")
plt.ylabel("Count of customer ")
# Out:
# Text(0, 0.5, 'Count of customer ')

# %% [markdown]
# In Mandalay city, Member type customer and normal type customer is similar. In Naypitaw city,  Member type customer is high and normal type customer is little bit low. In Yangon city  Member type customer is little bit low and normal type customer is high. There we see that normal type customer buy many thinghs highly.

# %%
#Create pivot table month and product wise maximum rating
rating_table=pd.pivot_table(d_frame,index=["Month"],values=["Rating"],columns=["Product line"],aggfunc=["max"])
rating_table.plot(kind="bar")
plt.title("Visualize rating of products on every month")
plt.ylabel("Maximum Rating")
# Out:
# Text(0, 0.5, 'Maximum Rating')

# %% [markdown]
# In every month ratings of every product is very good.
